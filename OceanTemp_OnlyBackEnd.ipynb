# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Ocean_Temperature.csv")
df.head()
# Out:
#   datetime      ocean_name   latitude   longitude      depth_m  salinity_psu  \
# 0  53:16.8   Pacific Ocean -22.582779  156.149792  4495.892131     37.400359
# 1  53:16.8    Arctic Ocean  81.128575   66.191923  5788.142873     36.277004
# 2  53:16.8  Atlantic Ocean  41.758910   11.365975   441.380125     33.756487
# 3  53:16.8           Other  17.758527 -168.242738   320.607614     31.410598
# 4  53:16.8  Southern Ocean -61.916645   -8.785371  5625.302024     37.093239
#
#          ph  chlorophyll_mg_m3  nitrate_umol_l  phosphate_umol_l  oxygen_ml_l  \
# 0  8.144205           1.247413        0.251422          2.092814     7.843628
# 1  8.418192           4.225716        5.685733          0.229743     7.436051
# 2  7.881336           0.779362        8.931902          1.755667     2.142172
# 3  8.265190           0.316588       10.878234          2.463062     4.911501
# 4  8.097687           1.150977        5.857062          1.169005     4.888622
#
# ...

# %%
df.drop(columns=["datetime"],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3838 entries, 0 to 3837
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ocean_name         3838 non-null   object
#  1   latitude           3838 non-null   float64
#  2   longitude          3838 non-null   float64
#  3   depth_m            3838 non-null   float64
#  4   salinity_psu       3838 non-null   float64
#  5   ph                 3838 non-null   float64
#  6   chlorophyll_mg_m3  3838 non-null   float64
#  7   nitrate_umol_l     3838 non-null   float64
#  8   phosphate_umol_l   3838 non-null   float64
#  9   oxygen_ml_l        3838 non-null   float64
#  10  current_speed_m_s  3838 non-null   float64
#  11  wind_speed_m_s     3838 non-null   float64
#  12  temperature_c      3838 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 389.9+ KB

# %%
df.describe()
# Out:
#           latitude    longitude      depth_m  salinity_psu           ph  \
# count  3838.000000  3838.000000  3838.000000   3838.000000  3838.000000
# mean     -0.346133    -2.289533  2976.513697     34.976781     8.008604
# std      52.252280   103.385322  1711.033101      2.925884     0.286962
# min     -89.997906  -179.988941     0.316962     30.001577     7.500252
# 25%     -45.809340   -91.843691  1517.971169     32.387933     7.764943
# 50%       0.273083    -4.179132  2952.998521     34.912043     8.014879
# 75%      45.034879    86.210388  4437.770675     37.589728     8.251542
# max      89.949181   179.805845  5998.039231     39.998051     8.499925
#
#        chlorophyll_mg_m3  nitrate_umol_l  phosphate_umol_l  oxygen_ml_l  \
# count        3838.000000     3838.000000       3838.000000  3838.000000
# mean            1.052448       19.948740          1.472050     4.489857
# std             1.049279       11.415284          0.858270     2.016842
# ...

# %%
df.isnull().sum()
# Out:
# ocean_name           0
# latitude             0
# longitude            0
# depth_m              0
# salinity_psu         0
# ph                   0
# chlorophyll_mg_m3    0
# nitrate_umol_l       0
# phosphate_umol_l     0
# oxygen_ml_l          0
# current_speed_m_s    0
# wind_speed_m_s       0
# temperature_c        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["ocean_name"]=LE.fit_transform(df["ocean_name"])
LE.classes_
# Out:
# array(['Arctic Ocean', 'Atlantic Ocean', 'Indian Ocean', 'Other',
#        'Pacific Ocean', 'Southern Ocean'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3838 entries, 0 to 3837
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ocean_name         3838 non-null   int64
#  1   latitude           3838 non-null   float64
#  2   longitude          3838 non-null   float64
#  3   depth_m            3838 non-null   float64
#  4   salinity_psu       3838 non-null   float64
#  5   ph                 3838 non-null   float64
#  6   chlorophyll_mg_m3  3838 non-null   float64
#  7   nitrate_umol_l     3838 non-null   float64
#  8   phosphate_umol_l   3838 non-null   float64
#  9   oxygen_ml_l        3838 non-null   float64
#  10  current_speed_m_s  3838 non-null   float64
#  11  wind_speed_m_s     3838 non-null   float64
#  12  temperature_c      3838 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 389.9 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["temperature_c"])
plt.show()

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       ocean_name   latitude   longitude      depth_m  salinity_psu        ph  \
# 0              4 -22.582779  156.149792  4495.892131     37.400359  8.144205
# 1              0  81.128575   66.191923  5788.142873     36.277004  8.418192
# 2              1  41.758910   11.365975   441.380125     33.756487  7.881336
# 3              3  17.758527 -168.242738   320.607614     31.410598  8.265190
# 4              5 -61.916645   -8.785371  5625.302024     37.093239  8.097687
# ...          ...        ...         ...          ...           ...       ...
# 3833           2 -20.770006   22.088097  2011.339081     35.642180  8.277892
# 3834           4  -7.357676  137.821137   252.268777     32.276866  8.312369
# 3835           1 -35.408540   10.012359  3589.426559     36.221976  8.073744
# 3836           0  77.859878    6.346738  5128.920318     30.121375  7.690154
# 3837           5 -68.644122   28.035749  2289.446327     34.886439  8.177041
#
# ...

# %%
y=df["temperature_c"]
y
# Out:
# 0      -16.111739
# 1      -35.680318
# 2       21.052229
# 3       24.067015
# 4      -31.324979
#           ...
# 3833     9.814185
# 3834    25.129599
# 3835   -10.364589
# 3836   -29.170964
# 3837     1.143936
# Name: temperature_c, Length: 3838, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

r2 = r2_score(ytest, ypred)

print("R-squared Score:", r2)
# Out:
# R-squared Score: 0.9740517505787147

# %%
#User Input Section
OceanName_L=['Arctic Ocean', 'Atlantic Ocean', 'Indian Ocean', 'Other', 'Pacific Ocean', 'Southern Ocean']
OceanName=input("Enter Ocean name: ")
OceanName_F=OceanName_L.index(OceanName)
latitude=float(input("Enter the Latitude: "))
longitude=float(input("Enter the Longitude: "))
depth_m=float(input("Enter the Depth in meter: "))
salinity_psu=float(input("Enter the Salinity PSU: "))
ph=float(input("Enter the pH: "))
chlorophyll_mg_m3=float(input("Enter the Chlorophll: "))
nitrate_umol_l=float(input("Enter the Nitrate: "))
phosphate_umol_l=float(input("Enter the Phosphate: "))
oxygen_ml_l=float(input("Enter the Oxygen: "))
current_speed_m_s=float(input("Enter the Current Speed: "))
wind_speed_m_s=float(input("Enter the Wind Speed: "))

pred=model.predict([[OceanName_F,latitude,longitude,depth_m,salinity_psu,ph,chlorophyll_mg_m3,
                     nitrate_umol_l,phosphate_umol_l,oxygen_ml_l,current_speed_m_s,wind_speed_m_s]])
print(pred)
# Out:
# Enter Ocean name: Arctic Ocean
# Enter the Latitude: -22.58
# Enter the Longitude: 156.14
# Enter the Depth in meter: 4495.89
# Enter the Salinity PSU: 37.4
# Enter the pH: 8.14
# Enter the Chlorophll: 1.24
# Enter the Nitrate: 0.25
# Enter the Phosphate: 2.09
# Enter the Oxygen: 7.84
# Enter the Current Speed: 2.9
# Enter the Wind Speed: 14.46
# [-18.98024581]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
